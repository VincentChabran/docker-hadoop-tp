# %%
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
from pyspark.sql import functions as F
import seaborn as sns

# %%
spark = SparkSession.builder \
    .appName("Analyse Immatriculations") \
    .config("spark.hadoop.hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql("USE concessionnaire")
client_immat_df = spark.sql("SELECT * FROM client_immatriculation_merged")

nombre_total_lignes = client_immat_df.count()
print(nombre_total_lignes)
client_immat_df.show(10)

#TODO A CHECK
test = spark.sql("SELECT * FROM client_processed")
test.select("age").distinct().show(1000)
# Out:
# 100000
# +---------------+---+-----+----+-------------------+---------------+---------------+----------+---------+-----------+--------+--------+-------+--------+--------+-------------+
# |immatriculation|age| sexe|taux|situationfamilliale|nbenfantacharge|deuxiemevoiture|    marque|puissance|   longueur|nbplaces|nbportes|couleur|occasion|    prix|modele_simple|
# +---------------+---+-----+----+-------------------+---------------+---------------+----------+---------+-----------+--------+--------+-------+--------+--------+-------------+
# |     1017 IM 82| 44|Homme|1042|          En Couple|              3|          false|       BMW|      507|très longue|       5|       5|   bleu|   false| 94800.0|           M5|
# |     1030 FY 50| 48|Homme| 156|          En Couple|              1|          false|      Ford|      125|     longue|       5|       5|   noir|    true| 16730.0|       Mondeo|
# |     1056 AC 82| 62|Homme| 163|          En Couple|              1|           true|Volkswagen|       55|     courte|       5|       3|   bleu|    true|  8540.0|         Polo|
# |      107 HH 65| 54|Femme| 906|        Célibataire|              0|          false|      Audi|       75|     courte|       5|       5|  blanc|   false| 18310.0|           A2|
# |      113 IQ 42| 30|Homme| 411|          En Couple|              1|          false|    Jaguar|      197|     longue|       5|       5|   bleu|    true| 25970.0|       X-Type|
# |     1137 WZ 96| 36|Homme| 485|          En Couple|              3|          false|   Renault|      245|très longue|       5|       5|   noir|   false| 49200.0|          Vel|
# |      115 ZB 91| 82|Femme|1196|        Célibataire|              0|          false|      Mini|      115|     courte|       5|       5|  blanc|   false| 18200.0|       Copper|
# |     1156 TK 37| 78|Homme| 588|          En Couple|              0|          false|  Mercedes|      306|très longue|       5|       5|   noir|    true| 70910.0|         S500|
# |     1175 MX 81| 26|Femme|1126|        Célibataire|              3|          false|       BMW|      507|très longue|       5|       5|   gris|   false| 94800.0|           M5|
# |     1179 JO 80| 73|Homme|1385|          En Couple|              0|          false|  Mercedes|      306|très longue|       5|       5|   gris|   false|101300.0|         S500|
# +---------------+---+-----+----+-------------------+---------------+---------------+----------+---------+-----------+--------+--------+-------+--------+--------+-------------+
# only showing top 10 rows
#
# +---+
# |age|
# +---+
# | 51|
# | 54|
# | -1|
# | 29|
# | 69|
# | 42|
# | 73|
# | 64|
# | 30|
# | 34|
# | 59|
# | 28|
# | 22|
# | 35|
# | 52|
# | 71|
# | 47|
# | 43|
# | 31|
# | 18|
# | 70|
# | 27|
# | 61|
# | 75|
# | 26|
# | 46|
# | 78|
# | 77|
# | 68|
# | 60|
# | 19|
# | 23|
# | 41|
# | 55|
# | 38|
# | 40|
# | 25|
# | 44|
# | 82|
# | 53|
# | 58|
# | 81|
# | 33|
# | 48|
# | 67|
# | 84|
# | 79|
# | 24|
# | 32|
# | 20|
# | 56|
# | 36|
# | 37|
# | 49|
# | 63|
# | 65|
# | 39|
# | 62|
# | 83|
# |   |
# |  ?|
# | 21|
# | 66|
# | 74|
# | 72|
# | 76|
# | 80|
# | 50|
# | 57|
# | 45|
# +---+

# %%
null_counts = {column: client_immat_df.filter(F.col(column).isNull()).count() for column in client_immat_df.columns}
print(null_counts)

client_immat_df.describe().show()

client_immat_df.select("modele_simple").distinct().show(100)
client_immat_df.select("longueur").distinct().show()
client_immat_df.select("marque").distinct().show()
client_immat_df.describe(["prix", "puissance"]).show()
# Out:
# {'immatriculation': 0, 'age': 0, 'sexe': 0, 'taux': 0, 'situationfamilliale': 0, 'nbenfantacharge': 0, 'deuxiemevoiture': 0, 'marque': 0, 'puissance': 0, 'longueur': 0, 'nbplaces': 0, 'nbportes': 0, 'couleur': 0, 'occasion': 0, 'prix': 0, 'modele_simple': 0}
# +-------+---------------+------------------+-------+-----------------+-------------------+------------------+---------------+------+-----------------+-----------+--------+------------------+-------+------------------+------------------+
# |summary|immatriculation|               age|   sexe|             taux|situationfamilliale|   nbenfantacharge|deuxiemevoiture|marque|        puissance|   longueur|nbplaces|          nbportes|couleur|              prix|     modele_simple|
# +-------+---------------+------------------+-------+-----------------+-------------------+------------------+---------------+------+-----------------+-----------+--------+------------------+-------+------------------+------------------+
# |  count|         100000|            100000| 100000|           100000|             100000|            100000|         100000|100000|           100000|     100000|  100000|            100000| 100000|            100000|            100000|
# |   mean|           NULL| 43.67146407953817|   NULL|        609.27469|               NULL|           1.25261|           NULL|  NULL|        199.77119|       NULL|     5.0|           4.86772|   NULL|       35911.88473| 537.4283826164867|
# | stddev|           NULL|18.287697385003813|   NULL|335.0840921155344|               NULL|1.3909124826082138|           NULL|  NULL|137.9558737938151|       NULL|     0.0|0.4970558039543675|   NULL|25872.637001368003|498.01795051960687|
# |    min|        0 AX 62|                  |  Femme|               -1|        Célibataire|                -1|          false|  Audi|               55|     courte|       5|                 3|  blanc|            7500.0|              1007|
# |    max|     9999 ZU 23|                 ?|Inconnu|             1399|           Marié(e)|                 4|           true| Volvo|              507|très longue|       5|                 5|  rouge|          101300.0|           Ypsilon|
# +-------+---------------+------------------+-------+-----------------+-------------------+------------------+---------------+------+-----------------+-----------+--------+------------------+-------+------------------+------------------+
#
# +-------------+
# |modele_simple|
# +-------------+
# |       Copper|
# |         Golf|
# |       X-Type|
# |           A2|
# |       Mondeo|
# |          S80|
# |         1007|
# |        Logan|
# |        Croma|
# |         Polo|
# |          Vel|
# |       Toledo|
# |      Ypsilon|
# |        Cuore|
# |       Laguna|
# |           M5|
# |       Maxima|
# |       Megane|
# |         A200|
# |         120i|
# |         S500|
# |      Picanto|
# |       Almera|
# |          9.3|
# |      Primera|
# |          New|
# |           A3|
# |       Superb|
# +-------------+
#
# +-----------+
# |   longueur|
# +-----------+
# |    moyenne|
# |très longue|
# |     courte|
# |     longue|
# +-----------+
#
# +----------+
# |    marque|
# +----------+
# |Volkswagen|
# |   Peugeot|
# |    Jaguar|
# |    Lancia|
# |      Mini|
# |       Kia|
# |     Volvo|
# |      Saab|
# |      Audi|
# |      Seat|
# |  Mercedes|
# |   Renault|
# |       BMW|
# |     Dacia|
# |     Skoda|
# |  Daihatsu|
# |    Nissan|
# |      Fiat|
# |      Ford|
# +----------+
#
# +-------+------------------+-----------------+
# |summary|              prix|        puissance|
# +-------+------------------+-----------------+
# |  count|            100000|           100000|
# |   mean|       35911.88473|        199.77119|
# | stddev|25872.637001368003|137.9558737938151|
# |    min|            7500.0|               55|
# |    max|          101300.0|              507|
# +-------+------------------+-----------------+

# %%
# Doublon à fix
immatriculation_counts = client_immat_df.groupBy("Immatriculation").agg(F.count("*").alias("nombre_occurences"))
doublons_immatriculation = immatriculation_counts.filter(F.col("nombre_occurences") > 1)

doublons_immatriculation.show(truncate=False)

doublons_list = [row["Immatriculation"] for row in doublons_immatriculation.collect()]
doublons_lignes = client_immat_df.filter(F.col("Immatriculation").isin(doublons_list))

doublons_lignes.show(truncate=False)
# Out:
# +---------------+-----------------+
# |Immatriculation|nombre_occurences|
# +---------------+-----------------+
# |3491 UO 84     |2                |
# |9643 KU 76     |2                |
# |4129 RI 55     |2                |
# |9387 QD 31     |2                |
# |7575 RU 54     |2                |
# |7139 HQ 38     |2                |
# |5064 CC 53     |2                |
# |8166 CW 64     |2                |
# |1769 OU 76     |2                |
# +---------------+-----------------+
#
# +---------------+---+-----+----+-------------------+---------------+---------------+----------+---------+-----------+--------+--------+-------+--------+--------+-------------+
# |immatriculation|age|sexe |taux|situationfamilliale|nbenfantacharge|deuxiemevoiture|marque    |puissance|longueur   |nbplaces|nbportes|couleur|occasion|prix    |modele_simple|
# +---------------+---+-----+----+-------------------+---------------+---------------+----------+---------+-----------+--------+--------+-------+--------+--------+-------------+
# |3491 UO 84     |30 |Homme|1014|En Couple          |4              |true           |BMW       |507      |très longue|5       |5       |bleu   |false   |94800.0 |M5           |
# |3491 UO 84     |43 |Homme|908 |En Couple          |4              |false          |BMW       |507      |très longue|5       |5       |bleu   |false   |94800.0 |M5           |
# |9643 KU 76     |45 |Femme|477 |Célibataire        |0              |false          |Renault   |170      |longue     |5       |5       |noir   |false   |27300.0 |Laguna       |
# |9643 KU 76     |35 |Homme|433 |Célibataire        |3              |false          |Renault   |170      |longue     |5       |5       |noir   |false   |27300.0 |Laguna       |
# |4129 RI 55     |49 |Homme|1225|Célibataire        |0              |false          |Renault   |170      |longue     |5       |5       |noir   |false   |27300.0 |Laguna       |
# |4129 RI 55     |26 |Femme|424 |En Couple          |0              |false          |Renault   |170      |longue     |5       |5       |noir   |false   |27300.0 |Laguna       |
# |9387 QD 31     |54 |Femme|463 |En Couple          |4              |false          |Audi      |75       |courte     |5       |5       |noir   |true    |12817.0 |A2           |
# |9387 QD 31     |23 |Homme|437 |En Couple          |1              |true           |Audi      |75       |courte     |5       |5       |noir   |true    |12817.0 |A2           |
# |7575 RU 54     |38 |Homme|535 |En Couple          |0              |false          |Volkswagen|55       |courte     |5       |3       |blanc  |false   |12200.0 |Polo         |
# |7575 RU 54     |32 |Homme|593 |En Couple          |2              |true           |Volkswagen|55       |courte     |5       |3       |blanc  |false   |12200.0 |Polo         |
# |7139 HQ 38     |18 |Femme|1303|En Couple          |1              |false          |Nissan    |109      |longue     |5       |5       |rouge  |false   |18650.0 |Primera      |
# |7139 HQ 38     |20 |Homme|220 |En Couple          |2              |false          |Nissan    |109      |longue     |5       |5       |rouge  |false   |18650.0 |Primera      |
# |1769 OU 76     |80 |Homme|207 |Célibataire        |0              |false          |Volkswagen|150      |moyenne    |5       |5       |noir   |false   |22900.0 |Golf         |
# |1769 OU 76     |39 |Homme|416 |Célibataire        |0              |false          |Volkswagen|150      |moyenne    |5       |5       |noir   |false   |22900.0 |Golf         |
# |5064 CC 53     |59 |Homme|404 |En Couple          |3              |true           |Mercedes  |306      |très longue|5       |5       |blanc  |false   |101300.0|S500         |
# |5064 CC 53     |64 |Femme|1353|En Couple          |3              |false          |Mercedes  |306      |très longue|5       |5       |blanc  |false   |101300.0|S500         |
# |8166 CW 64     |45 |Femme|191 |Célibataire        |1              |false          |Volkswagen|55       |courte     |5       |3       |noir   |false   |12200.0 |Polo         |
# |8166 CW 64     |24 |Femme|455 |En Couple          |0              |true           |Volkswagen|55       |courte     |5       |3       |noir   |false   |12200.0 |Polo         |
# +---------------+---+-----+----+-------------------+---------------+---------------+----------+---------+-----------+--------+--------+-------+--------+--------+-------------+

# %%
distribution_vehicules = client_immat_df.groupBy("situationfamilliale", "modele_simple").agg(F.count("*").alias("nombre_vehicules"))
distribution_vehicules.orderBy(F.desc("nombre_vehicules")).show()
# Out:
# +-------------------+-------------+----------------+
# |situationfamilliale|modele_simple|nombre_vehicules|
# +-------------------+-------------+----------------+
# |          En Couple|           M5|           12283|
# |        Célibataire|           A2|           10251|
# |          En Couple|       X-Type|            8168|
# |          En Couple|          S80|            5830|
# |          En Couple|          Vel|            5676|
# |          En Couple|         S500|            4892|
# |          En Couple|           A2|            3980|
# |          En Couple|          9.3|            3633|
# |          En Couple|        Croma|            3261|
# |          En Couple|       Mondeo|            3249|
# |          En Couple|       Laguna|            3155|
# |        Célibataire|         Polo|            3088|
# |        Célibataire|         1007|            2899|
# |        Célibataire|         Golf|            2609|
# |        Célibataire|       Megane|            2584|
# |        Célibataire|         A200|            2232|
# |        Célibataire|         120i|            1930|
# |          En Couple|         Polo|            1796|
# |          En Couple|         1007|            1796|
# |          En Couple|       Superb|            1602|
# +-------------------+-------------+----------------+
# only showing top 20 rows

# %%
distribution_vehicules_pandas = distribution_vehicules.toPandas()
top_10_distribution = distribution_vehicules_pandas.head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_distribution, x='situationfamilliale', y='nombre_vehicules', hue='modele_simple')

plt.xlabel('Situation Familiale')
plt.ylabel('Nombre de Véhicules')
plt.title('Modèle par situation familiale')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# Calculer la puissance moyenne par situation familiale
puissance_moyenne_par_situation = client_immat_df.groupBy("situationfamilliale").agg(F.avg("puissance").alias("puissance_moyenne"))
puissance_moyenne_par_situation.show()
# Out:
# +-------------------+------------------+
# |situationfamilliale| puissance_moyenne|
# +-------------------+------------------+
# |        Célibataire|115.09069355575869|
# |           Divorcée|237.38709677419354|
# |            Inconnu| 205.8357142857143|
# |          En Couple|245.61088539550582|
# |           Marié(e)| 240.9283536585366|
# +-------------------+------------------+

# %%
puissance_moyenne_par_situation_pandas = puissance_moyenne_par_situation.toPandas()

plt.figure(figsize=(10, 6))
sns.barplot(data=puissance_moyenne_par_situation_pandas, x="situationfamilliale", y="puissance_moyenne")
plt.xlabel('Situation Familiale')
plt.ylabel('Puissance Moyenne')
plt.title('Puissance moyenne par situation familiale')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calculer le prix moyen par tranche d'âge
prix_moyen_par_age = client_immat_df.groupBy("age").agg(F.avg("prix").alias("prix_moyen"))
prix_moyen_par_age.show(100)
# Out:
# +---+------------------+
# |age|        prix_moyen|
# +---+------------------+
# | 51| 33810.33313432836|
# | 54| 35202.37515299878|
# | -1| 34696.45161290323|
# | 69| 38683.71289537713|
# | 29| 34164.42144835774|
# | 42| 36153.70599022005|
# | 73| 38293.90476190476|
# | 64| 38341.69021065675|
# | 30| 35732.41701617735|
# | 34| 35317.94174174174|
# | 59| 34792.18279569892|
# | 28| 36227.43569131833|
# | 22| 35357.06060606061|
# | 52| 35736.42108397856|
# | 35| 34754.72862029647|
# | 71|39186.899868247696|
# | 47|34918.669239904986|
# | 43|34855.458157736306|
# | 31| 35022.73042438733|
# | 18| 35084.98725852856|
# | 70| 38519.09669211196|
# | 27| 35854.17519130085|
# | 61| 37130.81499395405|
# | 75|  37951.5124508519|
# | 26| 35417.14435062324|
# | 46|  35314.8425814234|
# | 78|  39539.2775564409|
# | 77| 38021.90051020408|
# | 68| 39455.44009779951|
# | 60| 34135.13430851064|
# | 19| 34860.75683168317|
# | 23| 35954.11881188119|
# | 41| 36287.78992628992|
# | 55|36237.702230259194|
# | 40| 35843.48424737456|
# | 38| 35993.66068222621|
# | 25| 35857.66262626262|
# | 44| 34894.06638503319|
# | 82| 37752.24816625917|
# | 53| 34555.82678132678|
# | 58| 34365.24474660074|
# | 81| 38299.36917562724|
# | 33|35457.455733808674|
# | 48| 35231.26586826347|
# | 67| 39126.54271356784|
# | 84| 39058.89585947302|
# | 79| 39005.06710526316|
# | 24|36039.232970576384|
# | 32| 34419.39665471923|
# | 20| 35456.83259911894|
# | 56|34720.987440191384|
# | 36| 35212.09473060983|
# | 37| 35070.56219512195|
# | 49| 35135.42044134727|
# | 63| 39565.69319640565|
# | 65|38587.535286284954|
# | 39| 35068.75409836065|
# | 62| 38779.26433915212|
# | 83| 37229.97752808989|
# |   |           36267.0|
# |  ?| 43289.55084745763|
# | 21| 35360.11565181855|
# | 66| 38609.72443890274|
# | 72| 40111.73187414501|
# | 74|  39343.2085492228|
# | 76|37219.161662817554|
# | 80| 38291.23429951691|
# | 50| 34744.32960565038|
# | 45|   36031.968216598|
# | 57| 34437.22890818858|
# +---+------------------+
